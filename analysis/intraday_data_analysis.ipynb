# %%
import json
import pandas as pd

# %matplotlib inline
fp = r"data/2019-4-11-FTFT.json"
# with open(fp, "r", encoding="utf8") as f:
#     content = f.read()
#     intra_day_data = json.loads(content)
#     print(len(intra_day_data))

df = pd.read_json(fp)
volume = df["marketVolume"]
volume_percentage = volume/volume.sum()

# %%
volume_percentage.plot()
